# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\Users\MOAYAD\AppData\Local\Programs\Python\Python313\Lib\site-packages (24.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
products=pd.read_pickle("cleaned data/products_001.pkl")
orders=pd.read_pickle("cleaned data/orders_001.pkl")
customers=pd.read_pickle("cleaned data/customers_001.pkl")

# %%
customers.head(5)
# Out:
#       customer_id        customer_name                 email  \
# 0  17670-51384-MA       Aloisia Allner     aallner0@lulu.com
# 1  73342-18763-UW           Piotr Bote       pbote1@yelp.com
# 2  21125-22134-PX        Jami Redholes  jredholes2@tmall.com
# 3  71253-00052-RN           Dene Azema  dazema3@facebook.com
# 4  23806-46781-OU  Christoffer O' Shea                   NaN
#
#           phone_number             address_line_1         city        country  \
# 0    +1 (862) 817-0124    57999 Pepper Wood Alley     Paterson  United States
# 1  +353 (913) 396-4653         2112 Ridgeway Hill      Crumlin        Ireland
# 2    +1 (210) 986-6806        5214 Bartillon Park  San Antonio  United States
# 3    +1 (217) 418-0714           27 Maywood Place  Springfield  United States
# 4  +353 (698) 362-9201  38980 Manitowish Junction   Cill Airne        Ireland
#
#   postcode loyalty_card
# 0     7505          Yes
# 1      D6W           No
# 2    78205          Yes
# 3    62711          Yes
# 4      N41           No

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     1000 non-null   str
#  1   customer_name   1000 non-null   str
#  2   email           796 non-null    str
#  3   phone_number    870 non-null    str
#  4   address_line_1  1000 non-null   str
#  5   city            1000 non-null   str
#  6   country         1000 non-null   category
#  7   postcode        1000 non-null   object
#  8   loyalty_card    1000 non-null   category
# dtypes: category(2), object(1), str(6)
# memory usage: 56.8+ KB

# %%
products.head(5)
orders.head(5)
# Out:
#         order_id order_date     customer_id product_id  quantity  \
# 0  QEV-37451-860 2019-09-05  17670-51384-MA      R-M-1         2
# 1  QEV-37451-860 2019-09-05  17670-51384-MA    E-M-0.5         5
# 2  FAA-43335-268 2021-06-17  21125-22134-PX      A-L-1         1
# 3  KAC-83089-793 2021-07-15  23806-46781-OU      E-M-1         2
# 4  KAC-83089-793 2021-07-15  23806-46781-OU    R-L-2.5         2
#
#    customer_name  email  country coffee_type roast_type size  unit_price  \
# 0            NaN    NaN      NaN         NaN        NaN  NaN         NaN
# 1            NaN    NaN      NaN         NaN        NaN  NaN         NaN
# 2            NaN    NaN      NaN         NaN        NaN  NaN         NaN
# 3            NaN    NaN      NaN         NaN        NaN  NaN         NaN
# 4            NaN    NaN      NaN         NaN        NaN  NaN         NaN
#
#    sales
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
# This prevents the 'ValueError: columns overlap' we saw earlier
cols_to_fix = ['customer_name', 'email', 'country']
orders = orders.drop(columns=cols_to_fix, errors='ignore')

# 3. Perform the Left Merge
# This matches every order to its customer details in one shot
orders = pd.merge(orders, customers[['customer_id', 'customer_name', 'email', 'country']], 
                  on='customer_id', 
                  how='left')

# %%
orders.head(5)
# Out:
#         order_id order_date     customer_id product_id  quantity  \
# 0  QEV-37451-860 2019-09-05  17670-51384-MA      R-M-1         2
# 1  QEV-37451-860 2019-09-05  17670-51384-MA    E-M-0.5         5
# 2  FAA-43335-268 2021-06-17  21125-22134-PX      A-L-1         1
# 3  KAC-83089-793 2021-07-15  23806-46781-OU      E-M-1         2
# 4  KAC-83089-793 2021-07-15  23806-46781-OU    R-L-2.5         2
#
#          customer_name                 email        country coffee_type  \
# 0       Aloisia Allner     aallner0@lulu.com  United States         Rob
# 1       Aloisia Allner     aallner0@lulu.com  United States         Exc
# 2        Jami Redholes  jredholes2@tmall.com  United States         Ara
# 3  Christoffer O' Shea                   NaN        Ireland         Exc
# 4  Christoffer O' Shea                   NaN        Ireland         Rob
#
#   roast_type  size  unit_price  profit
# 0          M   1.0       9.950   0.597
# 1          M   0.5       8.250   0.908
# 2          L   1.0      12.950   1.166
# 3          M   1.0      13.750   1.512
# 4          L   2.5      27.485   1.649

# %%
products.head(5)
# Out:
#   product_id coffee_type roast_type  size  unit_price  price_per_100g  profit
# 0    A-L-0.2         Ara          L   0.2       3.885           1.942   0.350
# 1    A-L-0.5         Ara          L   0.5       7.770           1.554   0.699
# 2      A-L-1         Ara          L   1.0      12.950           1.295   1.166
# 3    A-L-2.5         Ara          L   2.5      29.785           1.191   2.681
# 4    A-M-0.2         Ara          M   0.2       3.375           1.688   0.304

# %%
# 3. Perform the Left Merge
# This matches every order to its product details in one shot
orders = pd.merge(orders, products[['product_id', 'coffee_type', 'roast_type', 'size', 'unit_price','profit']], 
                  on='product_id', 
                  how='left')

# %%
orders.head(5)
# Out:
#         order_id order_date     customer_id        customer_name  \
# 0  QEV-37451-860 2019-09-05  17670-51384-MA       Aloisia Allner
# 1  QEV-37451-860 2019-09-05  17670-51384-MA       Aloisia Allner
# 2  FAA-43335-268 2021-06-17  21125-22134-PX        Jami Redholes
# 3  KAC-83089-793 2021-07-15  23806-46781-OU  Christoffer O' Shea
# 4  KAC-83089-793 2021-07-15  23806-46781-OU  Christoffer O' Shea
#
#                   email         city        country loyalty_card product_id  \
# 0     aallner0@lulu.com     Paterson  United States          Yes      R-M-1
# 1     aallner0@lulu.com     Paterson  United States          Yes    E-M-0.5
# 2  jredholes2@tmall.com  San Antonio  United States          Yes      A-L-1
# 3                   NaN   Cill Airne        Ireland           No      E-M-1
# 4                   NaN   Cill Airne        Ireland           No    R-L-2.5
#
#   coffee_type roast_type  size  quantity  unit_price  sales  profit_per_item  \
# 0         Rob          M   1.0         2       9.950  19.90            0.597
# 1         Exc          M   0.5         5       8.250  41.25            0.908
# 2         Ara          L   1.0         1      12.950  12.95            1.166
# 3         Exc          M   1.0         2      13.750  27.50            1.512
# 4         Rob          L   2.5         2      27.485  54.97            1.649
#
#    net_profit
# 0       1.194
# 1       4.540
# 2       1.166
# 3       3.024
# 4       3.298

# %%
# Delete columns ending with "_y" and rename columns ending with "_x" (remove "_x")
orders = orders.loc[:, ~orders.columns.str.endswith('_y')]
orders.columns = orders.columns.str.replace('_x', '', regex=False)

# %%
# Merge loyalty from customers with orders
orders = pd.merge(orders, customers[['customer_id', 'loyalty_card']], 
                  on='customer_id', 
                  how='left')

# %%
# Clean up duplicate loyalty columns
orders = orders.drop(columns=['loyalty_card_y'], errors='ignore')
orders = orders.rename(columns={'loyalty_card_x': 'loyalty_card'})

# %%
# Merge city from customers with orders
orders = pd.merge(orders, customers[['customer_id', 'city']], 
                  on='customer_id', 
                  how='left')

# %%
# Sort columns with logical order: Order Info → Customer Info → Product Info → Transaction Details
column_order = [
    'order_id', 'order_date',                    # Order identifiers
    'customer_id', 'customer_name', 'email', 'city', 'country', 'loyalty_card',  # Customer info
    'product_id', 'coffee_type', 'roast_type', 'size',  # Product info
    'quantity', 'unit_price', 'sales', 'profit_per_item', 'net_profit'  # Transaction details
]
orders = orders[column_order]

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         1000 non-null   str
#  1   order_date       1000 non-null   datetime64[us]
#  2   customer_id      1000 non-null   str
#  3   customer_name    1000 non-null   str
#  4   email            794 non-null    str
#  5   city             1000 non-null   str
#  6   country          1000 non-null   category
#  7   loyalty_card     1000 non-null   category
#  8   product_id       1000 non-null   str
#  9   coffee_type      1000 non-null   category
#  10  roast_type       1000 non-null   category
#  11  size             1000 non-null   float64
#  12  quantity         1000 non-null   int64
#  13  unit_price       1000 non-null   float64
#  14  sales            1000 non-null   float64
#  15  profit_per_item  1000 non-null   float64
#  16  net_profit       1000 non-null   float64
# dtypes: category(4), datetime64[us](1), float64(5), int64(1), str(6)
# memory usage: 105.8 KB

# %%
orders.rename(columns={'profit': 'profit_per_item'}, inplace=True)

# %%
orders['sales'] = orders['quantity'] * orders['unit_price']
orders['net_profit'] = orders['quantity'] * orders['profit_per_item']

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         1000 non-null   str
#  1   order_date       1000 non-null   datetime64[us]
#  2   customer_id      1000 non-null   str
#  3   product_id       1000 non-null   str
#  4   quantity         1000 non-null   int64
#  5   customer_name    1000 non-null   str
#  6   email            794 non-null    str
#  7   country          1000 non-null   category
#  8   coffee_type      1000 non-null   category
#  9   roast_type       1000 non-null   category
#  10  size             1000 non-null   float64
#  11  unit_price       1000 non-null   float64
#  12  profit_per_item  1000 non-null   float64
#  13  sales            1000 non-null   float64
#  14  net_profit       1000 non-null   float64
#  15  loyalty_card     1000 non-null   category
# dtypes: category(4), datetime64[us](1), float64(5), int64(1), str(5)
# memory usage: 98.0 KB

# %%
orders
# Out:
#           order_id order_date     customer_id        customer_name  \
# 0    QEV-37451-860 2019-09-05  17670-51384-MA       Aloisia Allner
# 1    QEV-37451-860 2019-09-05  17670-51384-MA       Aloisia Allner
# 2    FAA-43335-268 2021-06-17  21125-22134-PX        Jami Redholes
# 3    KAC-83089-793 2021-07-15  23806-46781-OU  Christoffer O' Shea
# 4    KAC-83089-793 2021-07-15  23806-46781-OU  Christoffer O' Shea
# ..             ...        ...             ...                  ...
# 995  RLM-96511-467 2020-01-06  43014-53743-XK     Jennica Tewelson
# 996  AEZ-13242-456 2022-05-04  62494-09113-RP    Marguerite Graves
# 997  UME-75640-698 2019-10-11  62494-09113-RP    Marguerite Graves
# 998  GJC-66474-557 2021-08-03  64965-78386-MY       Nicolina Jenny
# 999  IRV-20769-219 2020-10-15  77131-58092-GE    Vidovic Antonelli
#
#                        email         city         country loyalty_card  \
# 0          aallner0@lulu.com     Paterson   United States          Yes
# 1          aallner0@lulu.com     Paterson   United States          Yes
# 2       jredholes2@tmall.com  San Antonio   United States          Yes
# 3                        NaN   Cill Airne         Ireland           No
# 4                        NaN   Cill Airne         Ireland           No
# ..                       ...          ...             ...          ...
# 995  jtewelsonrn@samsung.com       Dallas   United States           No
# 996                      NaN   Fort Smith   United States           No
# 997                      NaN   Fort Smith   United States           No
# 998   njennyrq@bigcartel.com     Whittier   United States           No
# 999                      NaN       London  United Kingdom          Yes
#
#     product_id coffee_type roast_type  size  quantity  unit_price   sales  \
# 0        R-M-1         Rob          M   1.0         2       9.950  19.900
# 1      E-M-0.5         Exc          M   0.5         5       8.250  41.250
# 2        A-L-1         Ara          L   1.0         1      12.950  12.950
# 3        E-M-1         Exc          M   1.0         2      13.750  27.500
# 4      R-L-2.5         Rob          L   2.5         2      27.485  54.970
# ..         ...         ...        ...   ...       ...         ...     ...
# 995    R-L-2.5         Rob          L   2.5         1      27.485  27.485
# 996    R-M-0.5         Rob          M   0.5         5       5.970  29.850
# 997    A-M-0.5         Ara          M   0.5         4       6.750  27.000
# 998      A-D-1         Ara          D   1.0         1       9.950   9.950
# 999    E-M-0.2         Exc          M   0.2         3       4.125  12.375
#
#      profit_per_item  net_profit
# 0              0.597       1.194
# 1              0.908       4.540
# 2              1.166       1.166
# 3              1.512       3.024
# 4              1.649       3.298
# ..               ...         ...
# 995            1.649       1.649
# 996            0.358       1.790
# 997            0.607       2.428
# 998            0.895       0.895
# 999            0.454       1.362
#
# [1000 rows x 17 columns]
