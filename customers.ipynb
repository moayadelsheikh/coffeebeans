# %% [markdown]
# # Coffee Bean Sales

# %% [markdown]
# import needed libs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
tables = pd.read_excel('Raw Data.xlsx', sheet_name=None)

# %% [markdown]
# #### Extract the tables from the excel sheet

# %%
for table in tables:
    print(table)

orders = tables['orders']
customers = tables['customers']
# Out:
# orders
# customers
# products

# %% [markdown]
# #### Exploring the data

# %%
orders.head(5)
# Out:
#         Order ID Order Date     Customer ID Product ID  Quantity  \
# 0  QEV-37451-860 2019-09-05  17670-51384-MA      R-M-1         2
# 1  QEV-37451-860 2019-09-05  17670-51384-MA    E-M-0.5         5
# 2  FAA-43335-268 2021-06-17  21125-22134-PX      A-L-1         1
# 3  KAC-83089-793 2021-07-15  23806-46781-OU      E-M-1         2
# 4  KAC-83089-793 2021-07-15  23806-46781-OU    R-L-2.5         2
#
#    Customer Name  Email  Country  Coffee Type  Roast Type  Size  Unit Price  \
# 0            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 1            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 2            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 3            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 4            NaN    NaN      NaN          NaN         NaN   NaN         NaN
#
#    Sales
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
customers.head(5)
# Out:
#       Customer ID        Customer Name                 Email  \
# 0  17670-51384-MA       Aloisia Allner     aallner0@lulu.com
# 1  73342-18763-UW           Piotr Bote       pbote1@yelp.com
# 2  21125-22134-PX        Jami Redholes  jredholes2@tmall.com
# 3  71253-00052-RN           Dene Azema  dazema3@facebook.com
# 4  23806-46781-OU  Christoffer O' Shea                   NaN
#
#           Phone Number             Address Line 1         City        Country  \
# 0    +1 (862) 817-0124    57999 Pepper Wood Alley     Paterson  United States
# 1  +353 (913) 396-4653         2112 Ridgeway Hill      Crumlin        Ireland
# 2    +1 (210) 986-6806        5214 Bartillon Park  San Antonio  United States
# 3    +1 (217) 418-0714           27 Maywood Place  Springfield  United States
# 4  +353 (698) 362-9201  38980 Manitowish Junction   Cill Airne        Ireland
#
#   Postcode Loyalty Card
# 0     7505          Yes
# 1      D6W           No
# 2    78205          Yes
# 3    62711          Yes
# ...

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     1000 non-null   str
#  1   Customer Name   1000 non-null   str
#  2   Email           796 non-null    str
#  3   Phone Number    870 non-null    str
#  4   Address Line 1  1000 non-null   str
#  5   City            1000 non-null   str
#  6   Country         1000 non-null   str
#  7   Postcode        1000 non-null   object
#  8   Loyalty Card    1000 non-null   str
# dtypes: object(1), str(8)
# memory usage: 70.4+ KB

# %%
for column in customers.columns:
    print(f"the number of unique in '{column}': {customers[column].nunique()}")
# Out:
# the number of unique in 'Customer ID': 1000
# the number of unique in 'Customer Name': 1000
# the number of unique in 'Email': 796
# the number of unique in 'Phone Number': 870
# the number of unique in 'Address Line 1': 1000
# the number of unique in 'City': 386
# the number of unique in 'Country': 3
# the number of unique in 'Postcode': 629
# the number of unique in 'Loyalty Card': 2

# %%
customers['Country'] = customers['Country'].astype("category")
customers['Loyalty Card'] = customers['Loyalty Card'].astype("category")

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     1000 non-null   str
#  1   Customer Name   1000 non-null   str
#  2   Email           796 non-null    str
#  3   Phone Number    870 non-null    str
#  4   Address Line 1  1000 non-null   str
#  5   City            1000 non-null   str
#  6   Country         1000 non-null   category
#  7   Postcode        1000 non-null   object
#  8   Loyalty Card    1000 non-null   category
# dtypes: category(2), object(1), str(6)
# memory usage: 56.8+ KB

# %% [markdown]
# #### check for email validation

# %%
email_regex = r'^[^\s@]+@[^\s@]+\.[^\s@]+$'

customers[customers['Email'].str.contains(email_regex, regex=True)]
# Out:
#         Customer ID      Customer Name                      Email  \
# 0    17670-51384-MA     Aloisia Allner          aallner0@lulu.com
# 1    73342-18763-UW         Piotr Bote            pbote1@yelp.com
# 2    21125-22134-PX      Jami Redholes       jredholes2@tmall.com
# 3    71253-00052-RN         Dene Azema       dazema3@facebook.com
# 6    65223-29612-CB      Shaylynn Lobe           slobe6@nifty.com
# ..              ...                ...                        ...
# 986  51277-93873-RP      Claudell Ayre       cayrere@symantec.com
# 987  84405-83364-DG   Lorianne Kyneton  lkynetonrf@macromedia.com
# 990  98051-37183-SK  Dierdre Scrigmour      dscrigmourri@cnbc.com
# 995  43014-53743-XK   Jennica Tewelson    jtewelsonrn@samsung.com
# 998  64965-78386-MY     Nicolina Jenny     njennyrq@bigcartel.com
#
#             Phone Number            Address Line 1           City  \
# 0      +1 (862) 817-0124   57999 Pepper Wood Alley       Paterson
# ...

# %%
customers['Phone Number'].str.len().unique()
# Out:
# array([17., 19., nan, 18.])

# %%
customers.head()
# Out:
#       Customer ID        Customer Name                 Email  \
# 0  17670-51384-MA       Aloisia Allner     aallner0@lulu.com
# 1  73342-18763-UW           Piotr Bote       pbote1@yelp.com
# 2  21125-22134-PX        Jami Redholes  jredholes2@tmall.com
# 3  71253-00052-RN           Dene Azema  dazema3@facebook.com
# 4  23806-46781-OU  Christoffer O' Shea                   NaN
#
#           Phone Number             Address Line 1         City        Country  \
# 0    +1 (862) 817-0124    57999 Pepper Wood Alley     Paterson  United States
# 1  +353 (913) 396-4653         2112 Ridgeway Hill      Crumlin        Ireland
# 2    +1 (210) 986-6806        5214 Bartillon Park  San Antonio  United States
# 3    +1 (217) 418-0714           27 Maywood Place  Springfield  United States
# 4  +353 (698) 362-9201  38980 Manitowish Junction   Cill Airne        Ireland
#
#   Postcode Loyalty Card
# 0     7505          Yes
# 1      D6W           No
# 2    78205          Yes
# 3    62711          Yes
# ...

# %% [markdown]
# #### Standardize customers columns names for better integration

# %%
customers.columns
# Out:
# Index(['Customer ID', 'Customer Name', 'Email', 'Phone Number',
#        'Address Line 1', 'City', 'Country', 'Postcode', 'Loyalty Card'],
#       dtype='str')

# %%
customers.columns = customers.columns.str.lower().str.replace(' ', '_')
customers.columns
# Out:
# Index(['customer_id', 'customer_name', 'email', 'phone_number',
#        'address_line_1', 'city', 'country', 'postcode', 'loyalty_card'],
#       dtype='str')

# %% [markdown]
# #### even with the small amount of null values We will keep it because it's all in the contact info which is not going to effect analysis

# %%
print(f" null values: {customers.isna().sum().sum() / (customers.shape[0] * customers.shape[1])*100}%")
# Out:
#  null values: 3.711111111111111%

# %% [markdown]
# #### Standardize orders columns names for better integration

# %%
print(f"columns names of orders after: {orders.columns}")
orders.columns = orders.columns.str.lower().str.replace(' ', '_')
print(f"columns names of orders before: {orders.columns}")
# Out:
# columns names of orders after: Index(['Order ID', 'Order Date', 'Customer ID', 'Product ID', 'Quantity',
#        'Customer Name', 'Email', 'Country', 'Coffee Type', 'Roast Type',
#        'Size', 'Unit Price', 'Sales'],
#       dtype='str')
# columns names of orders before: Index(['order_id', 'order_date', 'customer_id', 'product_id', 'quantity',
#        'customer_name', 'email', 'country', 'coffee_type', 'roast_type',
#        'size', 'unit_price', 'sales'],
#       dtype='str')

# %%
git remote add origin https://github.com/moayadelsheikh/coffeebeans.git
git branch -M main
git push -u origin main
