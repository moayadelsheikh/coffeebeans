# %%
import pandas as pd 
import numpy as np 
import seaborn as sns s
import matplotlib as plt
# %pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
customers = pd.read_excel("Raw Data.xlsx", sheet_name="customers")
orders = pd.read_excel("Raw Data.xlsx", sheet_name="orders")
products = pd.read_excel("Raw Data.xlsx", sheet_name="products")

# %%
products.head()
# Out:
#   Product ID Coffee Type Roast Type  Size  Unit Price  Price per 100g   Profit
# 0    A-L-0.2         Ara          L   0.2       3.885          1.9425  0.34965
# 1    A-L-0.5         Ara          L   0.5       7.770          1.5540  0.69930
# 2      A-L-1         Ara          L   1.0      12.950          1.2950  1.16550
# 3    A-L-2.5         Ara          L   2.5      29.785          1.1914  2.68065
# 4    A-M-0.2         Ara          M   0.2       3.375          1.6875  0.30375

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product ID      48 non-null     str
#  1   Coffee Type     48 non-null     str
#  2   Roast Type      48 non-null     str
#  3   Size            48 non-null     float64
#  4   Unit Price      48 non-null     float64
#  5   Price per 100g  48 non-null     float64
#  6   Profit          48 non-null     float64
# dtypes: float64(4), str(3)
# memory usage: 2.8 KB

# %%
products.rename(columns={"Product ID":"product_id"})
# Out:
#    product_id Coffee Type Roast Type  Size  Unit Price  Price per 100g  \
# 0     A-L-0.2         Ara          L   0.2       3.885          1.9425
# 1     A-L-0.5         Ara          L   0.5       7.770          1.5540
# 2       A-L-1         Ara          L   1.0      12.950          1.2950
# 3     A-L-2.5         Ara          L   2.5      29.785          1.1914
# 4     A-M-0.2         Ara          M   0.2       3.375          1.6875
# 5     A-M-0.5         Ara          M   0.5       6.750          1.3500
# 6       A-M-1         Ara          M   1.0      11.250          1.1250
# 7     A-M-2.5         Ara          M   2.5      25.875          1.0350
# 8     A-D-0.2         Ara          D   0.2       2.985          1.4925
# 9     A-D-0.5         Ara          D   0.5       5.970          1.1940
# 10      A-D-1         Ara          D   1.0       9.950          0.9950
# 11    A-D-2.5         Ara          D   2.5      22.885          0.9154
# ...

# %%
products.columns=products.columns.str.lower().str.replace(" ","_")
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      48 non-null     str
#  1   coffee_type     48 non-null     str
#  2   roast_type      48 non-null     str
#  3   size            48 non-null     float64
#  4   unit_price      48 non-null     float64
#  5   price_per_100g  48 non-null     float64
#  6   profit          48 non-null     float64
# dtypes: float64(4), str(3)
# memory usage: 2.8 KB

# %%
products.info()
